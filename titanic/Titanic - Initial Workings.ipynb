# %% [markdown]
# #Titanic - Initial Data Exploration and model fitting

# %%
import numpy as np
import pandas as pd
# %pylab inline
import seaborn as sns
from pandasql import sqldf
import matplotlib.pyplot as plt
from ggplot import *

pysqldf = lambda q: sqldf(q, globals())
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f', 'xlim', 'ylim']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#Read in training dataset
training_data = pd.read_csv('train.csv', sep = ',')

#fix column names to make life easier...
training_data.columns = ['id', 'survived', 'class', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked']

#Display training data
training_data.head(n=10)
# Out:
#    id  survived  class                                               name  \
# 0   1         0      3                            Braund, Mr. Owen Harris
# 1   2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1      3                             Heikkinen, Miss. Laina
# 3   4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0      3                           Allen, Mr. William Henry
# 5   6         0      3                                   Moran, Mr. James
# 6   7         0      1                            McCarthy, Mr. Timothy J
# 7   8         0      3                     Palsson, Master. Gosta Leonard
# 8   9         1      3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9  10         1      2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       sex  age  sibsp  parch            ticket     fare cabin embarked
# 0    male   22      1      0         A/5 21171   7.2500   NaN        S
# 1  female   38      1      0          PC 17599  71.2833   C85        C
# 2  female   26      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female   35      1      0            113803  53.1000  C123        S
# 4    male   35      0      0            373450   8.0500   NaN        S
# 5    male  NaN      0      0            330877   8.4583   NaN        Q
# 6    male   54      0      0             17463  51.8625   E46        S
# 7    male    2      3      1            349909  21.0750   NaN        S
# 8  female   27      0      2            347742  11.1333   NaN        S
# 9  female   14      1      0            237736  30.0708   NaN        C

# %% [markdown]
# ##Exploratory Data Analysis
# Firstly a quick exploration of the key features and dimensions of the training data and a check for missing data

# %% [markdown]
# ###Understanding the key question, how many passengers in the training set survived?

# %%
pd.DataFrame(training_data.groupby('survived').count()['id'])
# Out:
#            id
# survived
# 0         549
# 1         342

# %% [markdown]
# This means that of a total of 891 passengers, 62% did not survive. This forms the benchmark for our future predictions as if we had no information we could guess that a given passenger would not survive with an accuracy of 62% assuming that the training dataset is a good representation of the population.

# %%
print 'Data Frame of ' + str(training_data.shape[0]) + ' rows and ' + str(training_data.shape[1]) + ' columns'
training_data.count()
# Out:
# Data Frame of 891 rows and 12 columns
# id          891
# survived    891
# class       891
# name        891
# sex         891
# age         714
# sibsp       891
# parch       891
# ticket      891
# fare        891
# cabin       204
# embarked    889
# dtype: int64

# %% [markdown]
# There are 3 variables that have missing data - Age, Cabin and Embarked. In the case of the latter 2, this likely means that this attribute didn't exist however for age it is clearly a missing value. Under different circumstances it might be prudent to remove these records from the dataset however given the small size of the dataset and the fact that predictions may be necessary on records that have the same problem, a strategy for imputing these values needs to be found.
#
# ###Plot below shows that passenger class and age are likely to be useful dimensions in being able to impute age more accurately.

# %%
ggplot(aes(x = 'class', y = 'age', color = 'sex'), data = training_data) + geom_point(position = 'jitter')
# Out:
# <ggplot: (294877157)>

# %%
ages = pd.DataFrame(training_data.groupby(['class', 'sex']).median()['age']).reset_index()
print 'Median ages of passengers by class and sex:'
ages
# Out:
# Median ages of passengers by class and sex:
#    class     sex   age
# 0      1  female  35.0
# 1      1    male  40.0
# 2      2  female  28.0
# 3      2    male  30.0
# 4      3  female  21.5
# 5      3    male  25.0

# %% [markdown]
# ###Use pandasql to join ages table to training data and impute the age where missing.

# %%
impute_ages_query = '''
SELECT
    t.id, 
    t.survived,
    t.class,
    t.name,
    t.sex,
    (CASE WHEN t.age > 0 THEN t.age ELSE a.age END) AS age,
    t.sibsp,
    t.parch,
    t.ticket,
    t.fare,
    t.cabin,
    t.embarked
FROM training_data t
LEFT JOIN ages a on a.class = t.class and a.sex = t.sex
'''
training_data = pysqldf(impute_ages_query)
training_data.head(n = 10)
# Out:
#    id  survived  class                                               name  \
# 0   1         0      3                            Braund, Mr. Owen Harris
# 1   2         1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1      3                             Heikkinen, Miss. Laina
# 3   4         1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0      3                           Allen, Mr. William Henry
# 5   6         0      3                                   Moran, Mr. James
# 6   7         0      1                            McCarthy, Mr. Timothy J
# 7   8         0      3                     Palsson, Master. Gosta Leonard
# 8   9         1      3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9  10         1      2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       sex  age  sibsp  parch            ticket     fare cabin embarked
# 0    male   22      1      0         A/5 21171   7.2500  None        S
# 1  female   38      1      0          PC 17599  71.2833   C85        C
# 2  female   26      0      0  STON/O2. 3101282   7.9250  None        S
# 3  female   35      1      0            113803  53.1000  C123        S
# 4    male   35      0      0            373450   8.0500  None        S
# 5    male   25      0      0            330877   8.4583  None        Q
# 6    male   54      0      0             17463  51.8625   E46        S
# 7    male    2      3      1            349909  21.0750  None        S
# 8  female   27      0      2            347742  11.1333  None        S
# 9  female   14      1      0            237736  30.0708  None        C

# %%
plt.figure(figsize=(15, 6))
ax = sns.boxplot(x = 'sex', y = 'fare', hue = 'survived', data = training_data)
ax.set(ylim=(0, 300))
# Out:
# [(0, 300)]

# %%
plt.figure(figsize=(15, 6))
ax = sns.boxplot(x = 'sex', y = 'fare', hue = 'survived', data = training_data)
ax.set(ylim=(0, 200))
# Out:
# [(0, 200)]

# %%
plt.figure(figsize=(15, 6))
ax = sns.boxplot(x = 'embarked', y = 'fare', hue = 'survived', data = training_data)
ax.set(ylim=(0, 200))
# Out:
# [(0, 200)]

# %%
plt.figure(figsize=(15, 6))
sns.set_color_codes("muted")
sns.barplot(x="embarked", y="survived", data=training_data,
            label="survived", color="b")

# %% [markdown]
# Histogram of Fare Distribution

# %%
plt.figure(figsize=(15, 6))
ax = sns.distplot(training_data['fare'])
ax.set(xlim=(0, 200))
# Out:
# [(0, 200)]

# %% [markdown]
# Add dummy variables for point of embarcation

# %%
training_data = pd.concat([training_data, pd.get_dummies(training_data['embarked'], prefix = 'embarked_at')], axis = 1)

# %% [markdown]
# Add dummy variables for sex

# %%
training_data = pd.concat([training_data, pd.get_dummies(training_data['sex'])], axis = 1)

# %%
def cabin_status(row):
    if row['cabin'] == None:
        return 0
    else:
        return 1
    
training_data['in_cabin'] = training_data.apply(cabin_status, axis = 1)

# %%
plt.figure(figsize=(15, 15))
sns.pairplot(training_data[['survived', 'class', 'female', 'age', 'fare', 'cabin', 'embarked_at_C', 'embarked_at_Q']], hue = 'survived')

# %%
corr = training_data.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3,
            square=True, xticklabels=5, yticklabels=5,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

corr
# Out:
#                      id  survived     class       age     sibsp     parch  \
# id             1.000000 -0.005007 -0.035144  0.039033 -0.057527 -0.001652
# survived      -0.005007  1.000000 -0.338481 -0.059579 -0.035322  0.081629
# class         -0.035144 -0.338481  1.000000 -0.413583  0.083081  0.018443
# age            0.039033 -0.059579 -0.413583  1.000000 -0.249854 -0.175526
# sibsp         -0.057527 -0.035322  0.083081 -0.249854  1.000000  0.414838
# parch         -0.001652  0.081629  0.018443 -0.175526  0.414838  1.000000
# fare           0.012658  0.257307 -0.549500  0.122692  0.159651  0.216225
# embarked_at_C -0.001205  0.168240 -0.243292  0.041114 -0.059528 -0.011069
# embarked_at_Q -0.033606  0.003650  0.221009 -0.092418 -0.026354 -0.081228
# embarked_at_S  0.022148 -0.155660  0.081720  0.014208  0.070941  0.063036
# female        -0.042939  0.543351 -0.131900 -0.102706  0.114631  0.245489
# male           0.042939 -0.543351  0.131900  0.102706 -0.114631 -0.245489
# in_cabin       0.019919  0.316912 -0.725541  0.277022 -0.040460  0.036987
#
#                    fare  embarked_at_C  embarked_at_Q  embarked_at_S  \
# id             0.012658      -0.001205      -0.033606       0.022148
# survived       0.257307       0.168240       0.003650      -0.155660
# class         -0.549500      -0.243292       0.221009       0.081720
# age            0.122692       0.041114      -0.092418       0.014208
# sibsp          0.159651      -0.059528      -0.026354       0.070941
# parch          0.216225      -0.011069      -0.081228       0.063036
# fare           1.000000       0.269335      -0.117216      -0.166603
# embarked_at_C  0.269335       1.000000      -0.148258      -0.778359
# embarked_at_Q -0.117216      -0.148258       1.000000      -0.496624
# embarked_at_S -0.166603      -0.778359      -0.496624       1.000000
# female         0.182333       0.082853       0.074115      -0.125722
# male          -0.182333      -0.082853      -0.074115       0.125722
# in_cabin       0.482075       0.208528      -0.129572      -0.110087
#
#                  female      male  in_cabin
# id            -0.042939  0.042939  0.019919
# survived       0.543351 -0.543351  0.316912
# class         -0.131900  0.131900 -0.725541
# age           -0.102706  0.102706  0.277022
# sibsp          0.114631 -0.114631 -0.040460
# parch          0.245489 -0.245489  0.036987
# fare           0.182333 -0.182333  0.482075
# embarked_at_C  0.082853 -0.082853  0.208528
# embarked_at_Q  0.074115 -0.074115 -0.129572
# embarked_at_S -0.125722  0.125722 -0.110087
# female         1.000000 -1.000000  0.140391
# male          -1.000000  1.000000 -0.140391
# in_cabin       0.140391 -0.140391  1.000000

# %% [markdown]
# ##Cluster the passengers using K means

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %% [markdown]
# Grab relevant columns from dataset and standardise for Kmeans

# %%
X = training_data[['class', 'age', 'sibsp', 'parch', 'embarked_at_Q', 'embarked_at_S', 'in_cabin']].values
X = StandardScaler().fit_transform(X)
X
# Out:
# array([[ 0.82737724, -0.53489116,  0.43279337, ..., -0.30756234,
#          0.61930636, -0.54492498],
#        [-1.56610693,  0.66839176,  0.43279337, ..., -0.30756234,
#         -1.61470971,  1.835115  ],
#        [ 0.82737724, -0.23407043, -0.4745452 , ..., -0.30756234,
#          0.61930636, -0.54492498],
#        ...,
#        [ 0.82737724, -0.57249375,  0.43279337, ..., -0.30756234,
#          0.61930636, -0.54492498],
#        [-1.56610693, -0.23407043, -0.4745452 , ..., -0.30756234,
#         -1.61470971,  1.835115  ],
#        [ 0.82737724,  0.21716066, -0.4745452 , ...,  3.25137334,
#         -1.61470971, -0.54492498]])

# %%
inertia = []
silh = []
cluster_ct = []
for i in range(2,20):
    k = KMeans(n_clusters = i)
    clusters = k.fit(X)
    inertia.append(clusters.inertia_)
    silh.append(silhouette_score(X, clusters.labels_))
    cluster_ct.append(i)

# %%
plt.figure(figsize=(15, 6))
plt.plot(inertia)
plt.title('Total Distance from Centroids by Cluster', fontsize = 20)

# %%
plt.figure(figsize=(15, 6))
plt.plot(silh)
plt.title('Silhouette Score by Cluster', fontsize = 20)

# %% [markdown]
# Both charts above suggest that the number optimal number of clusters may be found on the second loop of the process which equates to 4 clusters. The relatively low silhouette scores suggest that the clustering may not yield many additional insights.

# %%
k = KMeans(n_clusters = 4)
final_clusters = k.fit(X).labels_
final_clusters = pd.DataFrame(final_clusters)
final_clusters.columns = ['cluster']

# %%
training_data = pd.concat([training_data, final_clusters], axis = 1)

# %% [markdown]
# ...do some exploration of clusters.......

# %% [markdown]
# ##Fit some simple models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn import cross_validation, tree, metrics, svm
from sklearn.naive_bayes import GaussianNB, MultinomialNB

# %% [markdown]
# ###Logistic Regression
# Create dataset of key features for prediction

# %%
X = training_data[['class', 'female', 'age', 'fare']].values
y = training_data['survived'].values

# %%
#initiate model
log_reg = LogisticRegression()

#fit model
log_reg.fit(X, y)

#predict y based on X
y_predicted = log_reg.predict(X)

#compare predicted y to y
print accuracy_score(y, y_predicted)
print log_reg.coef_
# Out:
# 0.800224466891
# [[ -1.09350815e+00   2.48187765e+00  -3.12072552e-02   1.39090096e-03]]

# %% [markdown]
# Its a good score but probably overfitting! Lets try with cross validation!

# %%
log_reg = LogisticRegression()
scores = cross_validation.cross_val_score(log_reg, X, y, cv=20)
average(scores)
# Out:
# 0.79336297760210805

# %% [markdown]
# ###Decision Tree

# %%
dt = tree.DecisionTreeClassifier()
scores = cross_validation.cross_val_score(dt, X, y, cv=10)
average(scores)
# Out:
# 0.79582595619112484

# %%
dt = tree.DecisionTreeClassifier()
dt.set_params(min_samples_leaf = 5)
dt.set_params(max_depth = 5)
scores = cross_validation.cross_val_score(dt, X, y, cv=10)
#print metrics.classification_report(y, dt.predict(X))
mean(scores)
# Out:
# 0.81151884008625585

# %%
#use pydot
import StringIO

#install pydot
import pydot
import pyparsing

# %%
dt.fit(X, y)
dot_data = StringIO.StringIO()
tree.export_graphviz(dt, out_file=dot_data)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
graph.write_pdf('dt.pdf')
print '\nimage created!'
# Out:
# image created!

# %% [markdown]
# ###Naive Bayes

# %%
gnb = GaussianNB()
scores = cross_validation.cross_val_score(gnb, X, y, cv=10)
mean(scores)
# Out:
# 0.77669844512541142

# %%
mnb = MultinomialNB()
scores = cross_validation.cross_val_score(mnb, X, y, cv=10)
mean(scores)
# Out:
# 0.69722080354102833

# %% [markdown]
# ###K Nearest Neighbours

# %%
scores = []

for i in range(2,20):
    kn = KNeighborsClassifier(n_neighbors=i)
    scores.append(mean(cross_validation.cross_val_score(kn, X, y, cv = 10)))

plt.figure(figsize=(15, 6))
plt.plot(scores)

# %% [markdown]
# Pretty poor results, lets try standardising the variables:

# %%
X_stand = StandardScaler().fit_transform(X)

# %%
scores = []

for i in range(2,20):
    kn = KNeighborsClassifier(n_neighbors=i)
    scores.append(mean(cross_validation.cross_val_score(kn, X_stand, y, cv = 10)))

plt.figure(figsize=(15, 6))    
plt.plot(scores)

# %% [markdown]
# Much better!! More or less tops out on the 3rd loop which is k of 4.

# %% [markdown]
# **Support Vector Machine**

# %%
sup = svm.SVC(kernel = 'rbf',gamma=0.8, C=5)
scores = cross_validation.cross_val_score(sup, X_stand, y, cv = 10)
mean(scores)
# Out:
# 0.81372914538644869
