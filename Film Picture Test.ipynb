# %%
# %pylab inline
from scipy import misc
pulp = misc.imread('pulp.png')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
type(pulp)
pulp.shape
# Out:
# (595, 1026, 4)

# %%
import matplotlib.pyplot as plt
plt.imshow(pulp, cmap=plt.cm.gray)

# %%
U, s, V = np.linalg.svd(pulp)
print shape(U)
print shape(s)
print shape(V)
# Out:
# (595, 1026, 1026)
# (595, 4)
# (595, 4, 4)

# %%
S = 3
Sig = mat(np.eye(S) * s[:S])
U_reduced = U[:,:S]
V_reduced = V[:S, :]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-f8d35abf409f> in <module>()
#       1 S = 3
# ----> 2 Sig = mat(np.eye(S) * s[:S])
#       3 U_reduced = U[:,:S]
#       4 V_reduced = V[:S, :]
#
# ValueError: operands could not be broadcast together with shapes (3,3) (3,4)

# %%
pulp_rec = U_reduced * Sig * V_reduced
plt.imshow(pulp, cmap=plt.cm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-a54e5f40e152> in <module>()
# ----> 1 pulp_rec = U_reduced * Sig * V_reduced
#       2 plt.imshow(pulp, cmap=plt.cm)
#
# /Users/jacobbarnett/anaconda/lib/python2.7/site-packages/numpy/matrixlib/defmatrix.pyc in __rmul__(self, other)
#     345
#     346     def __rmul__(self, other):
# --> 347         return N.dot(other, self)
#     348
#     349     def __imul__(self, other):
#
# ValueError: shapes (360,3,640) and (3,3) not aligned: 640 (dim 2) != 3 (dim 0)
